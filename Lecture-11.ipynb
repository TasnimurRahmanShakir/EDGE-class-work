# %%
with open('Tasnim.txt', 'r') as file:
  content = file.read()
  print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-99f7860cec40> in <cell line: 1>()
# ----> 1 with open('https://docs.google.com/document/d/1QekmAbA-la7wNeMFftIllJiBzaAnsYqhDuIa62Kf4_c/edit?usp=sharing', 'r') as file:
#       2   content = file.read()
#       3   print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://docs.google.com/document/d/1QekmAbA-la7wNeMFftIllJiBzaAnsYqhDuIa62Kf4_c/edit?usp=sharing'

# %%
print(123)
print("Hello world")
# Out:
# 123
# Hello world

# %%
x = 12.4
y = 14
print(x)
print(y)
print(x,y)
print(f'x = {x}, y = {y}')
print(f'x = {x:.2f}  y = {y:.2f}')
print('x = ', x, 'y = ', y)
print('x = '+str(x)+' y = '+str(y))
x = x + 10
print(x)
# Out:
# 12.4
# 14
# 12.4 14
# x = 12.4, y = 14
# x = 12.40  y = 14.00
# x =  12.4 y =  14
# x = 12.4 y = 14
# 22.4

# %%
name, age, city = 'Tasnim' , 23, 'Dhaka'
print(name, age, city)

a = b = 'Python'
print(f'a = {a} \nb = {b}')
# Out:
# Tasnim 23 Dhaka
# a = Python,
# b = Python

# %%
PI  = 3.1416
r = input('Enter radius: ')
area = PI * float(r) ** 2
print(f'Area = {area:.2f}')
# Out:
# Enter radius: 5
# Area = 78.54

# %%
a = 10
b = 20
a, b = b, a
print(f'a = {a} \nb = {b}')
# Out:
# a = 20
# b = 10

# %%
p = input('Enter Principal: ')
R = input('Enter inerest rate: ')
T = input('Enter time(years): ')
I = (float(p) * float(R) * float(T)) / 100
print(f'Interest = {I:.2f}')
# Out:
# Enter Principal: 100
# Enter inerest rate: 5
# Enter time(years): 2
# Interest = 10.00

# %%
celcius = 37
fahrenheit = (celcius * 9/5) + 32
print(f'fahrenheit = {fahrenheit:.2f}')
# Out:
# fahrenheit = 98.60

# %%
length = input('Enter length: ')
width = input('Enter width: ')
area = float(length) * float(width)
perimeter = 2 * (float(length) + float(width))
print(f'Area = {area:.2f}')
print(f'Perimeter = {perimeter:.2f}')
# Out:
# Enter length: 5
# Enter width: 4
# Area = 20.00
# Perimeter = 18.00

# %% [markdown]
# precedence rules, priorities are:
#
# () > ** > */% > +-

# %% [markdown]
# x =  1+2*3-4/5^6
#   =  1+2*3-4/15625
#   =  1+2*3-0.000256
#   =  1+6-0.000256
#   =  6.9997444

# %%
print(type(12.33))
print(type('Hello world'))
print(type(True))
print(type(12))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>

# %%
noun = 'Tasnim'
date = 'Monday'

str = f'''How are you Mr. {noun}. You are invited to come to my house on {date}. Don't miss the chance'''
print(str)
# Out:
# How are you Mr. Tasnim. You are invited to come to my house on Monday. Don't miss the chance

# %%
hour = input('Enter hour: ')
rate = input('Enter rate: ')
pay = float(hour) * float(rate)
print(f'Pay = {pay:.2f}')
# Out:
# Enter hour: 35
# Enter rate: 2.75
# Pay = 96.25

# %%
print(n = 7)
print(7+5)
print(5.2, "this", 4 - 2, "that", 5/2.0)
# Out:
# 12
# 5.2 this 2 that 2.5

# %%
a,b,c,d,e,f,g,h,i,j = 'All','works','and','no','play','makes','jack','a','dull','boy'
print(f'{a} {b} {c} {d} {e} {f} {g} {h} {i} {j}')
# Out:
# All works and no play makes jack a dull boy

# %%
var  = 6*(1-2)
print(var)
# Out:
# -6

# %%
'str1 = "Hello world"'
print(str1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-e1795ceb0ba3> in <cell line: 2>()
#       1 'str1 = "Hello world"'
# ----> 2 print(str1)
#
# NameError: name 'str1' is not defined

# %%
x = input()
print(type(x))
x =  raw_input()
print(type(x))
x = input()
print(x)
# Out:
# 5
# <class 'str'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-5e06bdff01d6> in <cell line: 3>()
#       1 x = input()
#       2 print(type(x))
# ----> 3 x =  raw_input()
#       4 print(type(x))
#       5 x = input()
#
# NameError: name 'raw_input' is not defined
